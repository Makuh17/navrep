# %% [markdown]
# ## Create the Model

# %%
import numpy as np
from crowd_sim.envs.policy.orca import ORCA
from crowd_sim.envs.utils.state import JointState
import CMap2D
import matplotlib.pyplot as plt
from map2d import gridshow

class Suicide(object):
    def __init__(self):
        pass

class FastmarchORCAPolicy(object):
    def __init__(self, suicide_if_stuck=False):
        self.simulator = ORCA()
        self.suicide_if_stuck = suicide_if_stuck
        self.map = CMap2D.CMap2D()
        self.grid_num = 100
        self.new = True

    def reset(self):
        self.new = True
        self.simulator.reset()        
    
    def predict(self, obs, env):
        self.simulator.time_step = env._get_dt()
        other_agent_states = [
            agent.get_observable_state() for agent in env.soadrl_sim.humans + env.soadrl_sim.other_robots]
        joint_state = JointState(env.soadrl_sim.robot.get_full_state(), other_agent_states)
        
        if self.new:
            #find an appropriate origin
            bbox = env.soadrl_sim.obstacle_vertices[-1]
            bbox_ll = np.array(bbox[-1])
            bbox_tr = np.array(bbox[1])
            self.map.origin[0] = bbox_ll[0] - 0.25
            self.map.origin[1] = bbox_ll[1] - 0.25
            
            #find the right resolution
            max_dim = max(bbox_tr-bbox_ll)
            #offset = 2*max_dim/self.grid_num
            self.map.set_resolution((max_dim+2*0.25)/self.grid_num)
            
            #initialise occupancy
            self.map._occupancy = np.ones((self.grid_num,self.grid_num), dtype = np.float32)
            bbox_ij = self.map.xy_to_ij(bbox)
            self.map._occupancy[bbox_ij[-1,0]:bbox_ij[1,0], bbox_ij[-1,1]:bbox_ij[1,1]] = 0
            
            radius = env.soadrl_sim.robot.radius*1.05
            for vertex in env.soadrl_sim.obstacle_vertices[:-1]:
                xy_min, xy_max = np.min(vertex, 0), np.max(vertex,0)
                xy_min -= radius
                xy_max += radius
                min_max_ij = self.map.xy_to_ij([xy_min,xy_max])
                self.map._occupancy[min_max_ij[0,0]:min_max_ij[1,0], min_max_ij[0,1]:min_max_ij[1,1]] = 1
            #self.map.HUGE_ = 100 * np.prod( self.map._occupancy.shape )
            #calculate the field
            goal = self.map.xy_to_ij([(env.soadrl_sim.robot.gx,env.soadrl_sim.robot.gy)])
            self.field = self.map.fastmarch(goal[0])
            
            self.new = False
        
            # only for vizualisation atm
            robot_pos_xy = (joint_state.self_state.px, joint_state.self_state.py)
            robot_pos_ij = self.map.xy_to_ij([robot_pos_xy])
            gridfmpath8, jumps = CMap2D.path_from_dijkstra_field(self.field, robot_pos_ij[0], connectedness= 8)
        robot_pos_xy = (joint_state.self_state.px, joint_state.self_state.py)
        robot_pos_ij = self.map.xy_to_ij([robot_pos_xy])
        gridfmpath8, jumps = CMap2D.path_from_dijkstra_field(self.field, robot_pos_ij[0], connectedness= 8) 
        
        if gridfmpath8.shape[0] > 15:
            virtual_goal = gridfmpath8[15]  # look forward in path
            virtual_goal[0] = (virtual_goal[0]*self.map.resolution())+self.map.origin[0]
            virtual_goal[1] = (virtual_goal[1]*self.map.resolution())+self.map.origin[1]
            joint_state.self_state.gx = virtual_goal[0]
            joint_state.self_state.gy = virtual_goal[1]
            
            if np.sqrt(joint_state.self_state.vx**2+joint_state.self_state.vy**2) < 0.25:
                virtual_goal = gridfmpath8[8]  # look forward in path
                virtual_goal[0] = (virtual_goal[0]*self.map.resolution())+self.map.origin[0]
                virtual_goal[1] = (virtual_goal[1]*self.map.resolution())+self.map.origin[1]
                idx = np.argmin([virtual_goal[0] - robot_pos_xy[0],virtual_goal[0] - robot_pos_xy[0]])
                if idx == 0:
                    joint_state.self_state.gx = robot_pos_xy[0] + np.sign(virtual_goal[0] - robot_pos_xy[0])#*(virtual_goal[1] - robot_pos_xy[1]) #virtual_goal[0]
                elif idx == 1:
                    joint_state.self_state.gy = robot_pos_xy[1] + np.sign(virtual_goal[1] - robot_pos_xy[1])#*(virtual_goal[0] - robot_pos_xy[0]) #virtual_goal[1]
            
        action = self.simulator.predict(
            joint_state,
            env.soadrl_sim.obstacle_vertices,
            env.soadrl_sim.robot,
        )
        if self.suicide_if_stuck:
            if action.v < 0.02:
                return Suicide()
        vx = action.v * np.cos(action.r)
        vy = action.v * np.sin(action.r)
        return np.array([vx, vy])
# Out:
# /home/mads/miniconda3/envs/NavRepEnv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/mads/miniconda3/envs/NavRepEnv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/mads/miniconda3/envs/NavRepEnv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/mads/miniconda3/envs/NavRepEnv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/mads/miniconda3/envs/NavRepEnv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/mads/miniconda3/envs/NavRepEnv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
import os
import warnings
from typing import Dict

import cv2  # pytype:disable=import-error
import numpy as np
from gym import spaces


#currently the episode length is not used
def alt_generate_expert_traj(env, n_episodes, episode_length=1000,render=True,
                         policy=FastmarchORCAPolicy(),save_path=None):
    actions = []
    observations = []
    rewards = []
    episode_returns = np.zeros((n_episodes,))
    episode_starts = []

    ep_idx = 0
    policy.reset()
    obs = env.reset()
    print(obs.shape)
    episode_starts.append(True)
    reward_sum = 0.0
    idx = 0
    while ep_idx < n_episodes:
        observations.append(obs)
        action = policy.predict(obs, env)
        if isinstance(action, Suicide):
            rew = 0
            action = np.array([0, 0, 0])
            done = True
        else:
            obs, reward, done, _ = env.step(action)
        
        actions.append(action)
        rewards.append(reward)
        episode_starts.append(done)
        reward_sum += reward
        if render:
            env.render()
        if done:
            obs = env.reset()
            policy.reset()
            episode_returns[ep_idx] = reward_sum
            reward_sum = 0.0
            ep_idx += 1
    
    if isinstance(env.observation_space, spaces.Box):
        observations = np.concatenate(observations).reshape((-1,) + env.observation_space.shape)
        
    if isinstance(env.action_space, spaces.Box):
        actions = np.concatenate(actions).reshape((-1,) + env.action_space.shape)
        
    rewards = np.array(rewards)
    episode_starts = np.array(episode_starts[:-1])

    assert len(observations) == len(actions)
    
    numpy_dict = {
        'actions': actions,
        'obs': observations,
        'rewards': rewards,
        'episode_returns': episode_returns,
        'episode_starts': episode_starts
    }  # type: Dict[str, np.ndarray]

    for key, val in numpy_dict.items():
        print(key, val.shape)

    if save_path is not None:
        np.savez(save_path, **numpy_dict)

    env.close()

    return numpy_dict

# %%
from navrep.envs.e2eenv import E2ENavRepEnv, E2E1DNavRepEnv
env = E2ENavRepEnv(silent=True, scenario='train', adaptive=False, collect_statistics=False)
env.soadrl_sim.human_num = 2
env.soadrl_sim.num_walls = 0
env.soadrl_sim.num_circles = 0
data_reg = alt_generate_expert_traj(env,500, save_path = 'FORCA_03', render=False)
# Out:
# Ros was not found, disabled.
# (4101,)
# actions (46965, 2)
# obs (46965, 4101)
# rewards (46965,)
# episode_returns (500,)
# episode_starts (46965,)

# %%
from stable_baselines import PPO2
from stable_baselines.gail import ExpertDataset
from navrep.tools.custom_policy import CustomPolicy, Custom1DPolicy, ARCH, _C
from navrep.envs.e2eenv import E2ENavRepEnv
env = E2ENavRepEnv(silent=True, scenario='train', adaptive=False, collect_statistics=False)
env.soadrl_sim.human_num = 2
env.soadrl_sim.num_walls = 0
env.soadrl_sim.num_circles = 0
dataset = ExpertDataset(expert_path='FORCA_03.npz',traj_limitation=1, batch_size=64)
#model = PPO2('MlpPolicy', env, verbose=1)
model = PPO2(CustomPolicy, env, verbose=1)
# Pretrain the PPO2 model
model.pretrain(dataset, n_epochs=250)

model.learn(20)
# Out:
# /home/mads/miniconda3/envs/NavRepEnv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/mads/miniconda3/envs/NavRepEnv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/mads/miniconda3/envs/NavRepEnv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/mads/miniconda3/envs/NavRepEnv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/mads/miniconda3/envs/NavRepEnv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/mads/miniconda3/envs/NavRepEnv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.
# Ros was not found, disabled.
# actions (46965, 2)
# obs (46965, 4101)
# rewards (46965,)
# episode_returns (500,)
# episode_starts (46965,)
# Total trajectories: 1
# Total transitions: 198
# Average returns: 92.21337929330646
# Std for returns: 17.35421397993279
# Wrapping the env in a DummyVecEnv.
# WARNING:tensorflow:From /home/mads/git/navrep/navrep/tools/custom_policy.py:87: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.conv2d instead.
# WARNING:tensorflow:From /home/mads/miniconda3/envs/NavRepEnv/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/mads/git/navrep/navrep/tools/custom_policy.py:99: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From /home/mads/miniconda3/envs/NavRepEnv/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Pretraining with Behavior Cloning...
# ==== Training progress 10.00% ====
# Epoch 25
# Training loss: 0.037464, Validation loss: 0.035362
#
# ==== Training progress 20.00% ====
# Epoch 50
# Training loss: 0.003323, Validation loss: 0.005271
#
# ==== Training progress 30.00% ====
# Epoch 75
# Training loss: 0.001349, Validation loss: 0.001952
#
# ==== Training progress 40.00% ====
# Epoch 100
# Training loss: 0.000456, Validation loss: 0.001476
#
# ==== Training progress 50.00% ====
# Epoch 125
# Training loss: 0.000616, Validation loss: 0.001587
#
# ==== Training progress 60.00% ====
# Epoch 150
# Training loss: 0.000384, Validation loss: 0.001424
#
# ==== Training progress 70.00% ====
# Epoch 175
# Training loss: 0.000264, Validation loss: 0.001252
#
# ==== Training progress 80.00% ====
# Epoch 200
# Training loss: 0.000206, Validation loss: 0.001160
#
# ==== Training progress 90.00% ====
# Epoch 225
# Training loss: 0.000288, Validation loss: 0.001329
#
# ==== Training progress 100.00% ====
# Epoch 250
# Training loss: 0.000130, Validation loss: 0.001068
#
# Pretraining done.

# %%
    model.learn(total_timesteps=20000)
# Out:
# --------------------------------------
# | approxkl           | 0.010692782   |
# | clipfrac           | 0.14648438    |
# | explained_variance | -0.0365       |
# | fps                | 82            |
# | n_updates          | 1             |
# | policy_entropy     | 2.8389537     |
# | policy_loss        | -0.0030652396 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 2.72e-05      |
# | total_timesteps    | 128           |
# | value_loss         | 24.098497     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0029471437  |
# | clipfrac           | 0.0234375     |
# | explained_variance | -0.021        |
# | fps                | 107           |
# | n_updates          | 2             |
# | policy_entropy     | 2.8404615     |
# | policy_loss        | 0.00021228776 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 1.56          |
# | total_timesteps    | 256           |
# | value_loss         | 11.196041     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.021050317  |
# | clipfrac           | 0.2890625    |
# | explained_variance | 0.193        |
# | fps                | 128          |
# | n_updates          | 3            |
# | policy_entropy     | 2.8431451    |
# | policy_loss        | -0.019950388 |
# | serial_timesteps   | 384          |
# | time_elapsed       | 2.75         |
# | total_timesteps    | 384          |
# | value_loss         | 19.78081     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0030060187 |
# | clipfrac           | 0.021484375  |
# | explained_variance | 0.241        |
# | fps                | 128          |
# | n_updates          | 4            |
# | policy_entropy     | 2.8462267    |
# | policy_loss        | -0.002254593 |
# | serial_timesteps   | 512          |
# | time_elapsed       | 3.75         |
# | total_timesteps    | 512          |
# | value_loss         | 25.321861    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0009733148 |
# | clipfrac           | 0.00390625   |
# | explained_variance | 0.323        |
# | fps                | 134          |
# | n_updates          | 5            |
# | policy_entropy     | 2.8474536    |
# | policy_loss        | 0.0003056468 |
# | serial_timesteps   | 640          |
# | time_elapsed       | 4.75         |
# | total_timesteps    | 640          |
# | value_loss         | 17.205988    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.012467848  |
# | clipfrac           | 0.1640625    |
# | explained_variance | 0.435        |
# | fps                | 142          |
# | n_updates          | 6            |
# | policy_entropy     | 2.848573     |
# | policy_loss        | -0.008000779 |
# | serial_timesteps   | 768          |
# | time_elapsed       | 5.7          |
# | total_timesteps    | 768          |
# | value_loss         | 5.158693     |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.006909703 |
# | clipfrac           | 0.078125    |
# | explained_variance | 0.291       |
# | fps                | 131         |
# | n_updates          | 7           |
# | policy_entropy     | 2.8490932   |
# | policy_loss        | -0.01770564 |
# | serial_timesteps   | 896         |
# | time_elapsed       | 6.61        |
# | total_timesteps    | 896         |
# | value_loss         | 10.895918   |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.008071885  |
# | clipfrac           | 0.109375     |
# | explained_variance | -0.00288     |
# | fps                | 137          |
# | n_updates          | 8            |
# | policy_entropy     | 2.8467534    |
# | policy_loss        | -0.010569035 |
# | serial_timesteps   | 1024         |
# | time_elapsed       | 7.58         |
# | total_timesteps    | 1024         |
# | value_loss         | 3.5048504    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.018847208  |
# | clipfrac           | 0.23828125   |
# | explained_variance | 0.902        |
# | fps                | 151          |
# | n_updates          | 9            |
# | policy_entropy     | 2.845124     |
# | policy_loss        | -0.026759656 |
# | serial_timesteps   | 1152         |
# | time_elapsed       | 8.51         |
# | total_timesteps    | 1152         |
# | value_loss         | 0.5193127    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.021411514  |
# | clipfrac           | 0.22070312   |
# | explained_variance | 0.135        |
# | fps                | 133          |
# | n_updates          | 10           |
# | policy_entropy     | 2.8453958    |
# | policy_loss        | -0.018943503 |
# | serial_timesteps   | 1280         |
# | time_elapsed       | 9.36         |
# | total_timesteps    | 1280         |
# | value_loss         | 23.388866    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.004636711  |
# | clipfrac           | 0.04296875   |
# | explained_variance | 0.191        |
# | fps                | 127          |
# | n_updates          | 11           |
# | policy_entropy     | 2.8437712    |
# | policy_loss        | -0.002637942 |
# | serial_timesteps   | 1408         |
# | time_elapsed       | 10.3         |
# | total_timesteps    | 1408         |
# | value_loss         | 1.7504168    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.004805124   |
# | clipfrac           | 0.0546875     |
# | explained_variance | 0.0808        |
# | fps                | 123           |
# | n_updates          | 12            |
# | policy_entropy     | 2.842449      |
# | policy_loss        | -0.0041524926 |
# | serial_timesteps   | 1536          |
# | time_elapsed       | 11.3          |
# | total_timesteps    | 1536          |
# | value_loss         | 7.282878      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.012025905  |
# | clipfrac           | 0.20117188   |
# | explained_variance | 0.3          |
# | fps                | 128          |
# | n_updates          | 13           |
# | policy_entropy     | 2.8409414    |
# | policy_loss        | -0.020855103 |
# | serial_timesteps   | 1664         |
# | time_elapsed       | 12.4         |
# | total_timesteps    | 1664         |
# | value_loss         | 4.2462707    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.012049365  |
# | clipfrac           | 0.18359375   |
# | explained_variance | -1.09        |
# | fps                | 130          |
# | n_updates          | 14           |
# | policy_entropy     | 2.838859     |
# | policy_loss        | -0.008224271 |
# | serial_timesteps   | 1792         |
# | time_elapsed       | 13.4         |
# | total_timesteps    | 1792         |
# | value_loss         | 1.261313     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0099286195 |
# | clipfrac           | 0.13671875   |
# | explained_variance | 0.73         |
# | fps                | 113          |
# | n_updates          | 15           |
# | policy_entropy     | 2.8323364    |
# | policy_loss        | -0.011215929 |
# | serial_timesteps   | 1920         |
# | time_elapsed       | 14.3         |
# | total_timesteps    | 1920         |
# | value_loss         | 1.5895432    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0034884773 |
# | clipfrac           | 0.03515625   |
# | explained_variance | 0.0149       |
# | fps                | 124          |
# | n_updates          | 16           |
# | policy_entropy     | 2.8278248    |
# | policy_loss        | 0.0012015917 |
# | serial_timesteps   | 2048         |
# | time_elapsed       | 15.5         |
# | total_timesteps    | 2048         |
# | value_loss         | 19.503702    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.008423332   |
# | clipfrac           | 0.115234375   |
# | explained_variance | -1.74         |
# | fps                | 124           |
# | n_updates          | 17            |
# | policy_entropy     | 2.8274465     |
# | policy_loss        | -7.908675e-05 |
# | serial_timesteps   | 2176          |
# | time_elapsed       | 16.5          |
# | total_timesteps    | 2176          |
# | value_loss         | 0.5663997     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0026842759 |
# | clipfrac           | 0.025390625  |
# | explained_variance | 0.384        |
# | fps                | 115          |
# | n_updates          | 18           |
# | policy_entropy     | 2.8278856    |
# | policy_loss        | -0.01403168  |
# | serial_timesteps   | 2304         |
# | time_elapsed       | 17.5         |
# | total_timesteps    | 2304         |
# | value_loss         | 11.139065    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.003334658   |
# | clipfrac           | 0.03515625    |
# | explained_variance | -1.83         |
# | fps                | 134           |
# | n_updates          | 19            |
# | policy_entropy     | 2.8271604     |
# | policy_loss        | -0.0036019722 |
# | serial_timesteps   | 2432          |
# | time_elapsed       | 18.6          |
# | total_timesteps    | 2432          |
# | value_loss         | 0.726214      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0006520224  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.057        |
# | fps                | 125           |
# | n_updates          | 20            |
# | policy_entropy     | 2.8249664     |
# | policy_loss        | -0.0047134943 |
# | serial_timesteps   | 2560          |
# | time_elapsed       | 19.6          |
# | total_timesteps    | 2560          |
# | value_loss         | 16.731773     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.002429578  |
# | clipfrac           | 0.025390625  |
# | explained_variance | 0.165        |
# | fps                | 124          |
# | n_updates          | 21           |
# | policy_entropy     | 2.8247998    |
# | policy_loss        | -0.001966516 |
# | serial_timesteps   | 2688         |
# | time_elapsed       | 20.6         |
# | total_timesteps    | 2688         |
# | value_loss         | 25.385038    |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.005412583 |
# | clipfrac           | 0.06640625  |
# | explained_variance | -0.715      |
# | fps                | 125         |
# | n_updates          | 22          |
# | policy_entropy     | 2.8261688   |
# | policy_loss        | -0.00995778 |
# | serial_timesteps   | 2816        |
# | time_elapsed       | 21.6        |
# | total_timesteps    | 2816        |
# | value_loss         | 16.077045   |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.0025206814 |
# | clipfrac           | 0.0234375    |
# | explained_variance | 0.33         |
# | fps                | 128          |
# | n_updates          | 23           |
# | policy_entropy     | 2.8289092    |
# | policy_loss        | 0.0009818521 |
# | serial_timesteps   | 2944         |
# | time_elapsed       | 22.7         |
# | total_timesteps    | 2944         |
# | value_loss         | 8.523007     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.007499389   |
# | clipfrac           | 0.1015625     |
# | explained_variance | 0.803         |
# | fps                | 141           |
# | n_updates          | 24            |
# | policy_entropy     | 2.8278098     |
# | policy_loss        | -0.0111373635 |
# | serial_timesteps   | 3072          |
# | time_elapsed       | 23.7          |
# | total_timesteps    | 3072          |
# | value_loss         | 1.2280612     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0022344808  |
# | clipfrac           | 0.015625      |
# | explained_variance | 0.287         |
# | fps                | 133           |
# | n_updates          | 25            |
# | policy_entropy     | 2.8249755     |
# | policy_loss        | -0.0022665302 |
# | serial_timesteps   | 3200          |
# | time_elapsed       | 24.6          |
# | total_timesteps    | 3200          |
# | value_loss         | 11.457827     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0006959573  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.256         |
# | fps                | 135           |
# | n_updates          | 26            |
# | policy_entropy     | 2.824544      |
# | policy_loss        | -0.0005384274 |
# | serial_timesteps   | 3328          |
# | time_elapsed       | 25.5          |
# | total_timesteps    | 3328          |
# | value_loss         | 1.2816399     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0017823337 |
# | clipfrac           | 0.005859375  |
# | explained_variance | 0.291        |
# | fps                | 105          |
# | n_updates          | 27           |
# | policy_entropy     | 2.8256912    |
# | policy_loss        | 0.0011211645 |
# | serial_timesteps   | 3456         |
# | time_elapsed       | 26.5         |
# | total_timesteps    | 3456         |
# | value_loss         | 24.346802    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00078666955 |
# | clipfrac           | 0.005859375   |
# | explained_variance | -0.376        |
# | fps                | 131           |
# | n_updates          | 28            |
# | policy_entropy     | 2.8277109     |
# | policy_loss        | -0.007930554  |
# | serial_timesteps   | 3584          |
# | time_elapsed       | 27.7          |
# | total_timesteps    | 3584          |
# | value_loss         | 14.646232     |
# --------------------------------------
# ------------------------------------
# | approxkl           | 0.015115971 |
# | clipfrac           | 0.22460938  |
# | explained_variance | -0.405      |
# | fps                | 128         |
# | n_updates          | 29          |
# | policy_entropy     | 2.826416    |
# | policy_loss        | -0.02073033 |
# | serial_timesteps   | 3712        |
# | time_elapsed       | 28.7        |
# | total_timesteps    | 3712        |
# | value_loss         | 2.759917    |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.0028009333 |
# | clipfrac           | 0.0234375    |
# | explained_variance | 0.374        |
# | fps                | 120          |
# | n_updates          | 30           |
# | policy_entropy     | 2.8254168    |
# | policy_loss        | -0.006008722 |
# | serial_timesteps   | 3840         |
# | time_elapsed       | 29.6         |
# | total_timesteps    | 3840         |
# | value_loss         | 2.8120673    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.008407773  |
# | clipfrac           | 0.13476562   |
# | explained_variance | 0.928        |
# | fps                | 124          |
# | n_updates          | 31           |
# | policy_entropy     | 2.8256536    |
# | policy_loss        | -0.021028057 |
# | serial_timesteps   | 3968         |
# | time_elapsed       | 30.7         |
# | total_timesteps    | 3968         |
# | value_loss         | 0.0644122    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0040771817  |
# | clipfrac           | 0.048828125   |
# | explained_variance | 0.51          |
# | fps                | 140           |
# | n_updates          | 32            |
# | policy_entropy     | 2.8257425     |
# | policy_loss        | -0.0016905582 |
# | serial_timesteps   | 4096          |
# | time_elapsed       | 31.7          |
# | total_timesteps    | 4096          |
# | value_loss         | 3.504218      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.004094008  |
# | clipfrac           | 0.068359375  |
# | explained_variance | -0.397       |
# | fps                | 139          |
# | n_updates          | 33           |
# | policy_entropy     | 2.8264155    |
# | policy_loss        | -0.005534011 |
# | serial_timesteps   | 4224         |
# | time_elapsed       | 32.7         |
# | total_timesteps    | 4224         |
# | value_loss         | 22.867111    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0055658175  |
# | clipfrac           | 0.076171875   |
# | explained_variance | -1.68         |
# | fps                | 141           |
# | n_updates          | 34            |
# | policy_entropy     | 2.8258445     |
# | policy_loss        | -0.0074736215 |
# | serial_timesteps   | 4352          |
# | time_elapsed       | 33.6          |
# | total_timesteps    | 4352          |
# | value_loss         | 0.24108319    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.00725742   |
# | clipfrac           | 0.10546875   |
# | explained_variance | 0.813        |
# | fps                | 111          |
# | n_updates          | 35           |
# | policy_entropy     | 2.8231344    |
# | policy_loss        | -0.014722215 |
# | serial_timesteps   | 4480         |
# | time_elapsed       | 34.5         |
# | total_timesteps    | 4480         |
# | value_loss         | 1.0118748    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0069959797 |
# | clipfrac           | 0.10546875   |
# | explained_variance | -0.00154     |
# | fps                | 133          |
# | n_updates          | 36           |
# | policy_entropy     | 2.818942     |
# | policy_loss        | -0.008103659 |
# | serial_timesteps   | 4608         |
# | time_elapsed       | 35.6         |
# | total_timesteps    | 4608         |
# | value_loss         | 30.010023    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.003364189  |
# | clipfrac           | 0.037109375  |
# | explained_variance | -0.707       |
# | fps                | 145          |
# | n_updates          | 37           |
# | policy_entropy     | 2.8199427    |
# | policy_loss        | -0.004694539 |
# | serial_timesteps   | 4736         |
# | time_elapsed       | 36.6         |
# | total_timesteps    | 4736         |
# | value_loss         | 0.036864575  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0029902938 |
# | clipfrac           | 0.033203125  |
# | explained_variance | 0.722        |
# | fps                | 119          |
# | n_updates          | 38           |
# | policy_entropy     | 2.823185     |
# | policy_loss        | -0.004166458 |
# | serial_timesteps   | 4864         |
# | time_elapsed       | 37.5         |
# | total_timesteps    | 4864         |
# | value_loss         | 0.21852036   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0039930134 |
# | clipfrac           | 0.044921875  |
# | explained_variance | 0.249        |
# | fps                | 136          |
# | n_updates          | 39           |
# | policy_entropy     | 2.8193014    |
# | policy_loss        | -0.00690088  |
# | serial_timesteps   | 4992         |
# | time_elapsed       | 38.5         |
# | total_timesteps    | 4992         |
# | value_loss         | 13.804825    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0037325113 |
# | clipfrac           | 0.048828125  |
# | explained_variance | 0.129        |
# | fps                | 134          |
# | n_updates          | 40           |
# | policy_entropy     | 2.8195198    |
# | policy_loss        | -0.006781538 |
# | serial_timesteps   | 5120         |
# | time_elapsed       | 39.5         |
# | total_timesteps    | 5120         |
# | value_loss         | 22.559576    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.006207201  |
# | clipfrac           | 0.0859375    |
# | explained_variance | 0.0497       |
# | fps                | 113          |
# | n_updates          | 41           |
# | policy_entropy     | 2.822724     |
# | policy_loss        | -0.012231717 |
# | serial_timesteps   | 5248         |
# | time_elapsed       | 40.4         |
# | total_timesteps    | 5248         |
# | value_loss         | 66.58905     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0030424863  |
# | clipfrac           | 0.033203125   |
# | explained_variance | -0.0691       |
# | fps                | 107           |
# | n_updates          | 42            |
# | policy_entropy     | 2.8229017     |
# | policy_loss        | -0.0061649284 |
# | serial_timesteps   | 5376          |
# | time_elapsed       | 41.6          |
# | total_timesteps    | 5376          |
# | value_loss         | 40.94303      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.007545494  |
# | clipfrac           | 0.1171875    |
# | explained_variance | 0.178        |
# | fps                | 132          |
# | n_updates          | 43           |
# | policy_entropy     | 2.823242     |
# | policy_loss        | -0.015143947 |
# | serial_timesteps   | 5504         |
# | time_elapsed       | 42.8         |
# | total_timesteps    | 5504         |
# | value_loss         | 0.42853245   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0038984842 |
# | clipfrac           | 0.044921875  |
# | explained_variance | -3.09        |
# | fps                | 140          |
# | n_updates          | 44           |
# | policy_entropy     | 2.823638     |
# | policy_loss        | -0.007706957 |
# | serial_timesteps   | 5632         |
# | time_elapsed       | 43.7         |
# | total_timesteps    | 5632         |
# | value_loss         | 0.7310035    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0022618314 |
# | clipfrac           | 0.0234375    |
# | explained_variance | -0.759       |
# | fps                | 120          |
# | n_updates          | 45           |
# | policy_entropy     | 2.8244917    |
# | policy_loss        | -0.010883289 |
# | serial_timesteps   | 5760         |
# | time_elapsed       | 44.6         |
# | total_timesteps    | 5760         |
# | value_loss         | 0.23063031   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0017332955  |
# | clipfrac           | 0.0078125     |
# | explained_variance | 0.0565        |
# | fps                | 98            |
# | n_updates          | 46            |
# | policy_entropy     | 2.8216553     |
# | policy_loss        | -0.0042689396 |
# | serial_timesteps   | 5888          |
# | time_elapsed       | 45.7          |
# | total_timesteps    | 5888          |
# | value_loss         | 21.041008     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.001775767   |
# | clipfrac           | 0.009765625   |
# | explained_variance | -1.94         |
# | fps                | 150           |
# | n_updates          | 47            |
# | policy_entropy     | 2.8182456     |
# | policy_loss        | -0.0042378954 |
# | serial_timesteps   | 6016          |
# | time_elapsed       | 47            |
# | total_timesteps    | 6016          |
# | value_loss         | 0.034052793   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0013857322  |
# | clipfrac           | 0.005859375   |
# | explained_variance | -0.00737      |
# | fps                | 136           |
# | n_updates          | 48            |
# | policy_entropy     | 2.813734      |
# | policy_loss        | -0.0005582182 |
# | serial_timesteps   | 6144          |
# | time_elapsed       | 47.8          |
# | total_timesteps    | 6144          |
# | value_loss         | 14.1213875    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00044420507 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0848        |
# | fps                | 140           |
# | n_updates          | 49            |
# | policy_entropy     | 2.8126862     |
# | policy_loss        | -0.002741885  |
# | serial_timesteps   | 6272          |
# | time_elapsed       | 48.8          |
# | total_timesteps    | 6272          |
# | value_loss         | 32.46269      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0012912509 |
# | clipfrac           | 0.009765625  |
# | explained_variance | 0.108        |
# | fps                | 143          |
# | n_updates          | 50           |
# | policy_entropy     | 2.8111129    |
# | policy_loss        | -0.005960171 |
# | serial_timesteps   | 6400         |
# | time_elapsed       | 49.7         |
# | total_timesteps    | 6400         |
# | value_loss         | 15.440982    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0049536484 |
# | clipfrac           | 0.05859375   |
# | explained_variance | 0.116        |
# | fps                | 115          |
# | n_updates          | 51           |
# | policy_entropy     | 2.811143     |
# | policy_loss        | -0.011783528 |
# | serial_timesteps   | 6528         |
# | time_elapsed       | 50.6         |
# | total_timesteps    | 6528         |
# | value_loss         | 47.62577     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.002179905  |
# | clipfrac           | 0.021484375  |
# | explained_variance | 0.0793       |
# | fps                | 108          |
# | n_updates          | 52           |
# | policy_entropy     | 2.8126051    |
# | policy_loss        | -0.014100983 |
# | serial_timesteps   | 6656         |
# | time_elapsed       | 51.7         |
# | total_timesteps    | 6656         |
# | value_loss         | 19.414278    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.002203567  |
# | clipfrac           | 0.015625     |
# | explained_variance | 0.371        |
# | fps                | 123          |
# | n_updates          | 53           |
# | policy_entropy     | 2.8146026    |
# | policy_loss        | -0.005998493 |
# | serial_timesteps   | 6784         |
# | time_elapsed       | 52.9         |
# | total_timesteps    | 6784         |
# | value_loss         | 17.51306     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0011962756 |
# | clipfrac           | 0.0078125    |
# | explained_variance | 0.912        |
# | fps                | 125          |
# | n_updates          | 54           |
# | policy_entropy     | 2.816965     |
# | policy_loss        | -0.008371787 |
# | serial_timesteps   | 6912         |
# | time_elapsed       | 53.9         |
# | total_timesteps    | 6912         |
# | value_loss         | 0.07166196   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.013248846  |
# | clipfrac           | 0.18359375   |
# | explained_variance | 0.597        |
# | fps                | 107          |
# | n_updates          | 55           |
# | policy_entropy     | 2.8182707    |
# | policy_loss        | -0.011100519 |
# | serial_timesteps   | 7040         |
# | time_elapsed       | 54.9         |
# | total_timesteps    | 7040         |
# | value_loss         | 0.14041089   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0006718865  |
# | clipfrac           | 0.001953125   |
# | explained_variance | 0.028         |
# | fps                | 113           |
# | n_updates          | 56            |
# | policy_entropy     | 2.820167      |
# | policy_loss        | -0.0014237976 |
# | serial_timesteps   | 7168          |
# | time_elapsed       | 56.1          |
# | total_timesteps    | 7168          |
# | value_loss         | 15.3555355    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.011921516   |
# | clipfrac           | 0.14648438    |
# | explained_variance | -2.94         |
# | fps                | 132           |
# | n_updates          | 57            |
# | policy_entropy     | 2.8233764     |
# | policy_loss        | -0.0113020595 |
# | serial_timesteps   | 7296          |
# | time_elapsed       | 57.2          |
# | total_timesteps    | 7296          |
# | value_loss         | 0.039728947   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.009199239  |
# | clipfrac           | 0.14453125   |
# | explained_variance | 0.73         |
# | fps                | 117          |
# | n_updates          | 58           |
# | policy_entropy     | 2.8236706    |
# | policy_loss        | -0.008175097 |
# | serial_timesteps   | 7424         |
# | time_elapsed       | 58.2         |
# | total_timesteps    | 7424         |
# | value_loss         | 0.53072745   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0055843247  |
# | clipfrac           | 0.046875      |
# | explained_variance | -0.399        |
# | fps                | 145           |
# | n_updates          | 59            |
# | policy_entropy     | 2.823057      |
# | policy_loss        | -0.0121619385 |
# | serial_timesteps   | 7552          |
# | time_elapsed       | 59.3          |
# | total_timesteps    | 7552          |
# | value_loss         | 0.33993202    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0020061266  |
# | clipfrac           | 0.017578125   |
# | explained_variance | 0.936         |
# | fps                | 146           |
# | n_updates          | 60            |
# | policy_entropy     | 2.8209102     |
# | policy_loss        | -0.0032023932 |
# | serial_timesteps   | 7680          |
# | time_elapsed       | 60.2          |
# | total_timesteps    | 7680          |
# | value_loss         | 0.031247362   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0018739555 |
# | clipfrac           | 0.00390625   |
# | explained_variance | -0.788       |
# | fps                | 119          |
# | n_updates          | 61           |
# | policy_entropy     | 2.821523     |
# | policy_loss        | -0.007417829 |
# | serial_timesteps   | 7808         |
# | time_elapsed       | 61.1         |
# | total_timesteps    | 7808         |
# | value_loss         | 0.13123265   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0018863986  |
# | clipfrac           | 0.013671875   |
# | explained_variance | -0.802        |
# | fps                | 146           |
# | n_updates          | 62            |
# | policy_entropy     | 2.8257995     |
# | policy_loss        | -0.0056279604 |
# | serial_timesteps   | 7936          |
# | time_elapsed       | 62.1          |
# | total_timesteps    | 7936          |
# | value_loss         | 0.5966212     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0056830514  |
# | clipfrac           | 0.078125      |
# | explained_variance | 0.193         |
# | fps                | 137           |
# | n_updates          | 63            |
# | policy_entropy     | 2.8296227     |
# | policy_loss        | -0.0148680145 |
# | serial_timesteps   | 8064          |
# | time_elapsed       | 63            |
# | total_timesteps    | 8064          |
# | value_loss         | 49.03845      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.010804167  |
# | clipfrac           | 0.15429688   |
# | explained_variance | 0.798        |
# | fps                | 140          |
# | n_updates          | 64           |
# | policy_entropy     | 2.8314059    |
# | policy_loss        | -0.013423372 |
# | serial_timesteps   | 8192         |
# | time_elapsed       | 63.9         |
# | total_timesteps    | 8192         |
# | value_loss         | 0.0063020946 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0011310444  |
# | clipfrac           | 0.00390625    |
# | explained_variance | -0.13         |
# | fps                | 138           |
# | n_updates          | 65            |
# | policy_entropy     | 2.8304534     |
# | policy_loss        | -0.0021987709 |
# | serial_timesteps   | 8320          |
# | time_elapsed       | 64.9          |
# | total_timesteps    | 8320          |
# | value_loss         | 27.733953     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.004014381  |
# | clipfrac           | 0.03515625   |
# | explained_variance | -0.05        |
# | fps                | 142          |
# | n_updates          | 66           |
# | policy_entropy     | 2.8314605    |
# | policy_loss        | -0.016989984 |
# | serial_timesteps   | 8448         |
# | time_elapsed       | 65.8         |
# | total_timesteps    | 8448         |
# | value_loss         | 7.2497354    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.006977746   |
# | clipfrac           | 0.091796875   |
# | explained_variance | -1.45         |
# | fps                | 134           |
# | n_updates          | 67            |
# | policy_entropy     | 2.8334827     |
# | policy_loss        | -0.0088167945 |
# | serial_timesteps   | 8576          |
# | time_elapsed       | 66.7          |
# | total_timesteps    | 8576          |
# | value_loss         | 0.018590242   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00492351    |
# | clipfrac           | 0.0625        |
# | explained_variance | 0.2           |
# | fps                | 134           |
# | n_updates          | 68            |
# | policy_entropy     | 2.8319755     |
# | policy_loss        | -0.0140492385 |
# | serial_timesteps   | 8704          |
# | time_elapsed       | 67.6          |
# | total_timesteps    | 8704          |
# | value_loss         | 0.14815713    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0051843887 |
# | clipfrac           | 0.033203125  |
# | explained_variance | 0.182        |
# | fps                | 139          |
# | n_updates          | 69           |
# | policy_entropy     | 2.8313994    |
# | policy_loss        | -0.0085732   |
# | serial_timesteps   | 8832         |
# | time_elapsed       | 68.6         |
# | total_timesteps    | 8832         |
# | value_loss         | 17.26098     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.002284834   |
# | clipfrac           | 0.01171875    |
# | explained_variance | 0.374         |
# | fps                | 146           |
# | n_updates          | 70            |
# | policy_entropy     | 2.8338778     |
# | policy_loss        | -0.0024841835 |
# | serial_timesteps   | 8960          |
# | time_elapsed       | 69.5          |
# | total_timesteps    | 8960          |
# | value_loss         | 0.008104824   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0067847227 |
# | clipfrac           | 0.078125     |
# | explained_variance | -0.0566      |
# | fps                | 140          |
# | n_updates          | 71           |
# | policy_entropy     | 2.832107     |
# | policy_loss        | -0.02423249  |
# | serial_timesteps   | 9088         |
# | time_elapsed       | 70.4         |
# | total_timesteps    | 9088         |
# | value_loss         | 13.18856     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0016791865  |
# | clipfrac           | 0.013671875   |
# | explained_variance | 0.0107        |
# | fps                | 140           |
# | n_updates          | 72            |
# | policy_entropy     | 2.8307126     |
# | policy_loss        | -0.0032037618 |
# | serial_timesteps   | 9216          |
# | time_elapsed       | 71.3          |
# | total_timesteps    | 9216          |
# | value_loss         | 18.26284      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0021698347 |
# | clipfrac           | 0.025390625  |
# | explained_variance | -0.205       |
# | fps                | 137          |
# | n_updates          | 73           |
# | policy_entropy     | 2.8303628    |
# | policy_loss        | -0.008938116 |
# | serial_timesteps   | 9344         |
# | time_elapsed       | 72.2         |
# | total_timesteps    | 9344         |
# | value_loss         | 32.762886    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0066815997 |
# | clipfrac           | 0.095703125  |
# | explained_variance | 0.0221       |
# | fps                | 142          |
# | n_updates          | 74           |
# | policy_entropy     | 2.8322504    |
# | policy_loss        | -0.013532538 |
# | serial_timesteps   | 9472         |
# | time_elapsed       | 73.1         |
# | total_timesteps    | 9472         |
# | value_loss         | 23.513313    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0075264936 |
# | clipfrac           | 0.1015625    |
# | explained_variance | 0.816        |
# | fps                | 143          |
# | n_updates          | 75           |
# | policy_entropy     | 2.8336906    |
# | policy_loss        | -0.014797421 |
# | serial_timesteps   | 9600         |
# | time_elapsed       | 74           |
# | total_timesteps    | 9600         |
# | value_loss         | 0.03743693   |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.008567578 |
# | clipfrac           | 0.12695312  |
# | explained_variance | 0.0362      |
# | fps                | 137         |
# | n_updates          | 76          |
# | policy_entropy     | 2.8311298   |
# | policy_loss        | -0.01843476 |
# | serial_timesteps   | 9728        |
# | time_elapsed       | 74.9        |
# | total_timesteps    | 9728        |
# | value_loss         | 52.07223    |
# ------------------------------------
# --------------------------------------
# | approxkl           | 0.0028297305  |
# | clipfrac           | 0.03125       |
# | explained_variance | -0.0364       |
# | fps                | 142           |
# | n_updates          | 77            |
# | policy_entropy     | 2.8297298     |
# | policy_loss        | -0.0040853834 |
# | serial_timesteps   | 9856          |
# | time_elapsed       | 75.9          |
# | total_timesteps    | 9856          |
# | value_loss         | 22.898432     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.03163338   |
# | clipfrac           | 0.26367188   |
# | explained_variance | 0.309        |
# | fps                | 141          |
# | n_updates          | 78           |
# | policy_entropy     | 2.8301778    |
# | policy_loss        | -0.033026252 |
# | serial_timesteps   | 9984         |
# | time_elapsed       | 76.8         |
# | total_timesteps    | 9984         |
# | value_loss         | 0.0358089    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0076370155  |
# | clipfrac           | 0.11328125    |
# | explained_variance | 0.617         |
# | fps                | 142           |
# | n_updates          | 79            |
# | policy_entropy     | 2.8300953     |
# | policy_loss        | -0.0060666883 |
# | serial_timesteps   | 10112         |
# | time_elapsed       | 77.7          |
# | total_timesteps    | 10112         |
# | value_loss         | 0.23664343    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.007130253  |
# | clipfrac           | 0.091796875  |
# | explained_variance | -0.5         |
# | fps                | 136          |
# | n_updates          | 80           |
# | policy_entropy     | 2.8275447    |
# | policy_loss        | -0.008331424 |
# | serial_timesteps   | 10240        |
# | time_elapsed       | 78.6         |
# | total_timesteps    | 10240        |
# | value_loss         | 0.0920642    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0021711793  |
# | clipfrac           | 0.017578125   |
# | explained_variance | -0.183        |
# | fps                | 127           |
# | n_updates          | 81            |
# | policy_entropy     | 2.8287213     |
# | policy_loss        | -0.0067426725 |
# | serial_timesteps   | 10368         |
# | time_elapsed       | 79.5          |
# | total_timesteps    | 10368         |
# | value_loss         | 0.03964949    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0039168843  |
# | clipfrac           | 0.044921875   |
# | explained_variance | -0.494        |
# | fps                | 107           |
# | n_updates          | 82            |
# | policy_entropy     | 2.8316765     |
# | policy_loss        | -0.0056418357 |
# | serial_timesteps   | 10496         |
# | time_elapsed       | 80.5          |
# | total_timesteps    | 10496         |
# | value_loss         | 0.13676518    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0063929916 |
# | clipfrac           | 0.0859375    |
# | explained_variance | 0.374        |
# | fps                | 122          |
# | n_updates          | 83           |
# | policy_entropy     | 2.8333604    |
# | policy_loss        | -0.009472513 |
# | serial_timesteps   | 10624        |
# | time_elapsed       | 81.7         |
# | total_timesteps    | 10624        |
# | value_loss         | 0.12132552   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0054764836  |
# | clipfrac           | 0.0625        |
# | explained_variance | 0.0726        |
# | fps                | 127           |
# | n_updates          | 84            |
# | policy_entropy     | 2.833929      |
# | policy_loss        | -0.0044024903 |
# | serial_timesteps   | 10752         |
# | time_elapsed       | 82.7          |
# | total_timesteps    | 10752         |
# | value_loss         | 0.096796945   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0065233763 |
# | clipfrac           | 0.091796875  |
# | explained_variance | -0.281       |
# | fps                | 129          |
# | n_updates          | 85           |
# | policy_entropy     | 2.8312304    |
# | policy_loss        | -0.009735026 |
# | serial_timesteps   | 10880        |
# | time_elapsed       | 83.7         |
# | total_timesteps    | 10880        |
# | value_loss         | 0.014710426  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0011620438  |
# | clipfrac           | 0.005859375   |
# | explained_variance | 0.802         |
# | fps                | 113           |
# | n_updates          | 86            |
# | policy_entropy     | 2.8289597     |
# | policy_loss        | -0.0019207168 |
# | serial_timesteps   | 11008         |
# | time_elapsed       | 84.7          |
# | total_timesteps    | 11008         |
# | value_loss         | 0.06588615    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0021674966  |
# | clipfrac           | 0.01171875    |
# | explained_variance | 0.037         |
# | fps                | 107           |
# | n_updates          | 87            |
# | policy_entropy     | 2.825919      |
# | policy_loss        | -0.0015246208 |
# | serial_timesteps   | 11136         |
# | time_elapsed       | 85.9          |
# | total_timesteps    | 11136         |
# | value_loss         | 31.881344     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.013562692  |
# | clipfrac           | 0.13476562   |
# | explained_variance | -0.0374      |
# | fps                | 110          |
# | n_updates          | 88           |
# | policy_entropy     | 2.8233945    |
# | policy_loss        | -0.016773978 |
# | serial_timesteps   | 11264        |
# | time_elapsed       | 87           |
# | total_timesteps    | 11264        |
# | value_loss         | 4.1889544    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0044741333 |
# | clipfrac           | 0.052734375  |
# | explained_variance | -0.684       |
# | fps                | 118          |
# | n_updates          | 89           |
# | policy_entropy     | 2.8217282    |
# | policy_loss        | -0.012054406 |
# | serial_timesteps   | 11392        |
# | time_elapsed       | 88.2         |
# | total_timesteps    | 11392        |
# | value_loss         | 0.0039183125 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0032655583 |
# | clipfrac           | 0.041015625  |
# | explained_variance | -0.837       |
# | fps                | 102          |
# | n_updates          | 90           |
# | policy_entropy     | 2.819804     |
# | policy_loss        | -0.013329823 |
# | serial_timesteps   | 11520        |
# | time_elapsed       | 89.3         |
# | total_timesteps    | 11520        |
# | value_loss         | 0.011721861  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0051869545 |
# | clipfrac           | 0.072265625  |
# | explained_variance | -0.229       |
# | fps                | 115          |
# | n_updates          | 91           |
# | policy_entropy     | 2.817813     |
# | policy_loss        | -0.004871986 |
# | serial_timesteps   | 11648        |
# | time_elapsed       | 90.5         |
# | total_timesteps    | 11648        |
# | value_loss         | 26.623438    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.010816023  |
# | clipfrac           | 0.15429688   |
# | explained_variance | -0.0069      |
# | fps                | 125          |
# | n_updates          | 92           |
# | policy_entropy     | 2.8152027    |
# | policy_loss        | -0.009628163 |
# | serial_timesteps   | 11776        |
# | time_elapsed       | 91.6         |
# | total_timesteps    | 11776        |
# | value_loss         | 18.517622    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.008503282  |
# | clipfrac           | 0.12109375   |
# | explained_variance | -1.01        |
# | fps                | 130          |
# | n_updates          | 93           |
# | policy_entropy     | 2.8160262    |
# | policy_loss        | -0.010457604 |
# | serial_timesteps   | 11904        |
# | time_elapsed       | 92.7         |
# | total_timesteps    | 11904        |
# | value_loss         | 0.06801568   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.02370887   |
# | clipfrac           | 0.265625     |
# | explained_variance | 0.214        |
# | fps                | 117          |
# | n_updates          | 94           |
# | policy_entropy     | 2.818502     |
# | policy_loss        | -0.021832101 |
# | serial_timesteps   | 12032        |
# | time_elapsed       | 93.6         |
# | total_timesteps    | 12032        |
# | value_loss         | 0.03992754   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.008829196  |
# | clipfrac           | 0.087890625  |
# | explained_variance | -0.065       |
# | fps                | 117          |
# | n_updates          | 95           |
# | policy_entropy     | 2.8206446    |
# | policy_loss        | -0.005052212 |
# | serial_timesteps   | 12160        |
# | time_elapsed       | 94.7         |
# | total_timesteps    | 12160        |
# | value_loss         | 24.280289    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.01292141   |
# | clipfrac           | 0.16992188   |
# | explained_variance | -0.408       |
# | fps                | 119          |
# | n_updates          | 96           |
# | policy_entropy     | 2.8205938    |
# | policy_loss        | -0.020754486 |
# | serial_timesteps   | 12288        |
# | time_elapsed       | 95.8         |
# | total_timesteps    | 12288        |
# | value_loss         | 0.004696717  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0045488244  |
# | clipfrac           | 0.0625        |
# | explained_variance | -0.0046       |
# ...
# | serial_timesteps   | 15872        |
# | time_elapsed       | 127          |
# | total_timesteps    | 15872        |
# | value_loss         | 14.624062    |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.010378609 |
# | clipfrac           | 0.12109375  |
# | explained_variance | 0.895       |
# | fps                | 142         |
# | n_updates          | 125         |
# | policy_entropy     | 2.8123817   |
# | policy_loss        | -0.01444242 |
# | serial_timesteps   | 16000       |
# | time_elapsed       | 128         |
# | total_timesteps    | 16000       |
# | value_loss         | 0.025773829 |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.027592342  |
# | clipfrac           | 0.265625     |
# | explained_variance | 0.656        |
# | fps                | 131          |
# | n_updates          | 126          |
# | policy_entropy     | 2.811382     |
# | policy_loss        | -0.008970124 |
# | serial_timesteps   | 16128        |
# | time_elapsed       | 129          |
# | total_timesteps    | 16128        |
# | value_loss         | 0.16682513   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.013675371  |
# | clipfrac           | 0.125        |
# | explained_variance | 0.496        |
# | fps                | 136          |
# | n_updates          | 127          |
# | policy_entropy     | 2.8110073    |
# | policy_loss        | -0.012636388 |
# | serial_timesteps   | 16256        |
# | time_elapsed       | 130          |
# | total_timesteps    | 16256        |
# | value_loss         | 12.987719    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.06362841   |
# | clipfrac           | 0.25390625   |
# | explained_variance | 0.445        |
# | fps                | 132          |
# | n_updates          | 128          |
# | policy_entropy     | 2.8116193    |
# | policy_loss        | -0.029559854 |
# | serial_timesteps   | 16384        |
# | time_elapsed       | 131          |
# | total_timesteps    | 16384        |
# | value_loss         | 23.692905    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.012830839  |
# | clipfrac           | 0.15625      |
# | explained_variance | -1.26        |
# | fps                | 137          |
# | n_updates          | 129          |
# | policy_entropy     | 2.8140423    |
# | policy_loss        | -0.008391108 |
# | serial_timesteps   | 16512        |
# | time_elapsed       | 132          |
# | total_timesteps    | 16512        |
# | value_loss         | 0.022231782  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.00720376   |
# | clipfrac           | 0.08203125   |
# | explained_variance | -4.98        |
# | fps                | 127          |
# | n_updates          | 130          |
# | policy_entropy     | 2.814162     |
# | policy_loss        | 0.0016914685 |
# | serial_timesteps   | 16640        |
# | time_elapsed       | 133          |
# | total_timesteps    | 16640        |
# | value_loss         | 0.025667585  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0054736184 |
# | clipfrac           | 0.06640625   |
# | explained_variance | 0.957        |
# | fps                | 127          |
# | n_updates          | 131          |
# | policy_entropy     | 2.8112116    |
# | policy_loss        | -0.010697059 |
# | serial_timesteps   | 16768        |
# | time_elapsed       | 134          |
# | total_timesteps    | 16768        |
# | value_loss         | 0.019921623  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0069806213  |
# | clipfrac           | 0.0859375     |
# | explained_variance | -0.0124       |
# | fps                | 139           |
# | n_updates          | 132           |
# | policy_entropy     | 2.808514      |
# | policy_loss        | -0.0037083882 |
# | serial_timesteps   | 16896         |
# | time_elapsed       | 135           |
# | total_timesteps    | 16896         |
# | value_loss         | 0.1863129     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.008939952  |
# | clipfrac           | 0.14453125   |
# | explained_variance | -1.53        |
# | fps                | 121          |
# | n_updates          | 133          |
# | policy_entropy     | 2.8065007    |
# | policy_loss        | -0.009366505 |
# | serial_timesteps   | 17024        |
# | time_elapsed       | 135          |
# | total_timesteps    | 17024        |
# | value_loss         | 0.07391751   |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.011406913 |
# | clipfrac           | 0.123046875 |
# | explained_variance | -0.94       |
# | fps                | 122         |
# | n_updates          | 134         |
# | policy_entropy     | 2.8058605   |
# | policy_loss        | -0.00907629 |
# | serial_timesteps   | 17152       |
# | time_elapsed       | 137         |
# | total_timesteps    | 17152       |
# | value_loss         | 0.29946962  |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.018705852  |
# | clipfrac           | 0.19921875   |
# | explained_variance | 0.148        |
# | fps                | 132          |
# | n_updates          | 135          |
# | policy_entropy     | 2.805413     |
# | policy_loss        | -0.024068138 |
# | serial_timesteps   | 17280        |
# | time_elapsed       | 138          |
# | total_timesteps    | 17280        |
# | value_loss         | 11.676206    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0056304056 |
# | clipfrac           | 0.072265625  |
# | explained_variance | -0.762       |
# | fps                | 126          |
# | n_updates          | 136          |
# | policy_entropy     | 2.8053439    |
# | policy_loss        | -0.011216825 |
# | serial_timesteps   | 17408        |
# | time_elapsed       | 139          |
# | total_timesteps    | 17408        |
# | value_loss         | 0.05196585   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.020901848  |
# | clipfrac           | 0.2421875    |
# | explained_variance | 0.171        |
# | fps                | 127          |
# | n_updates          | 137          |
# | policy_entropy     | 2.8064148    |
# | policy_loss        | -0.017805655 |
# | serial_timesteps   | 17536        |
# | time_elapsed       | 140          |
# | total_timesteps    | 17536        |
# | value_loss         | 0.041474313  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0079757795 |
# | clipfrac           | 0.08984375   |
# | explained_variance | -0.372       |
# | fps                | 121          |
# | n_updates          | 138          |
# | policy_entropy     | 2.8067653    |
# | policy_loss        | -0.012322485 |
# | serial_timesteps   | 17664        |
# | time_elapsed       | 141          |
# | total_timesteps    | 17664        |
# | value_loss         | 0.026387943  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.008532286  |
# | clipfrac           | 0.10546875   |
# | explained_variance | 0.83         |
# | fps                | 124          |
# | n_updates          | 139          |
# | policy_entropy     | 2.8059235    |
# | policy_loss        | -0.012795808 |
# | serial_timesteps   | 17792        |
# | time_elapsed       | 142          |
# | total_timesteps    | 17792        |
# | value_loss         | 0.016920332  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.013997012  |
# | clipfrac           | 0.140625     |
# | explained_variance | 0.0858       |
# | fps                | 126          |
# | n_updates          | 140          |
# | policy_entropy     | 2.806414     |
# | policy_loss        | -0.017433563 |
# | serial_timesteps   | 17920        |
# | time_elapsed       | 143          |
# | total_timesteps    | 17920        |
# | value_loss         | 20.265362    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.010187636  |
# | clipfrac           | 0.16015625   |
# | explained_variance | 0.953        |
# | fps                | 123          |
# | n_updates          | 141          |
# | policy_entropy     | 2.8099613    |
# | policy_loss        | -0.012180779 |
# | serial_timesteps   | 18048        |
# | time_elapsed       | 144          |
# | total_timesteps    | 18048        |
# | value_loss         | 0.007869248  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.03395559   |
# | clipfrac           | 0.28320312   |
# | explained_variance | -1.41        |
# | fps                | 114          |
# | n_updates          | 142          |
# | policy_entropy     | 2.81216      |
# | policy_loss        | -0.016394198 |
# | serial_timesteps   | 18176        |
# | time_elapsed       | 145          |
# | total_timesteps    | 18176        |
# | value_loss         | 0.026544288  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.06635766   |
# | clipfrac           | 0.29882812   |
# | explained_variance | -0.075       |
# | fps                | 116          |
# | n_updates          | 143          |
# | policy_entropy     | 2.8146193    |
# | policy_loss        | -0.026039273 |
# | serial_timesteps   | 18304        |
# | time_elapsed       | 146          |
# | total_timesteps    | 18304        |
# | value_loss         | 0.1216895    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0101804985  |
# | clipfrac           | 0.140625      |
# | explained_variance | 0.204         |
# | fps                | 123           |
# | n_updates          | 144           |
# | policy_entropy     | 2.8166077     |
# | policy_loss        | -0.0080695255 |
# | serial_timesteps   | 18432         |
# | time_elapsed       | 147           |
# | total_timesteps    | 18432         |
# | value_loss         | 17.685272     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.026011666  |
# | clipfrac           | 0.26953125   |
# | explained_variance | 0.438        |
# | fps                | 131          |
# | n_updates          | 145          |
# | policy_entropy     | 2.8203723    |
# | policy_loss        | -0.022628557 |
# | serial_timesteps   | 18560        |
# | time_elapsed       | 148          |
# | total_timesteps    | 18560        |
# | value_loss         | 0.012611636  |
# -------------------------------------
# ------------------------------------
# | approxkl           | 0.022658693 |
# | clipfrac           | 0.23632812  |
# | explained_variance | -0.648      |
# | fps                | 116         |
# | n_updates          | 146         |
# | policy_entropy     | 2.822815    |
# | policy_loss        | 0.018729813 |
# | serial_timesteps   | 18688       |
# | time_elapsed       | 149         |
# | total_timesteps    | 18688       |
# | value_loss         | 0.23400663  |
# ------------------------------------
# -------------------------------------
# | approxkl           | 0.008699426  |
# | clipfrac           | 0.091796875  |
# | explained_variance | -0.544       |
# | fps                | 112          |
# | n_updates          | 147          |
# | policy_entropy     | 2.8240342    |
# | policy_loss        | -0.013498986 |
# | serial_timesteps   | 18816        |
# | time_elapsed       | 150          |
# | total_timesteps    | 18816        |
# | value_loss         | 0.11712595   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.012057544  |
# | clipfrac           | 0.16601562   |
# | explained_variance | -3.66        |
# | fps                | 113          |
# | n_updates          | 148          |
# | policy_entropy     | 2.8250163    |
# | policy_loss        | -0.021111533 |
# | serial_timesteps   | 18944        |
# | time_elapsed       | 151          |
# | total_timesteps    | 18944        |
# | value_loss         | 0.013682337  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0076222476 |
# | clipfrac           | 0.083984375  |
# | explained_variance | -3.17        |
# | fps                | 119          |
# | n_updates          | 149          |
# | policy_entropy     | 2.8249855    |
# | policy_loss        | -0.021214064 |
# | serial_timesteps   | 19072        |
# | time_elapsed       | 152          |
# | total_timesteps    | 19072        |
# | value_loss         | 0.036810815  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.012918228  |
# | clipfrac           | 0.125        |
# | explained_variance | -0.00285     |
# | fps                | 120          |
# | n_updates          | 150          |
# | policy_entropy     | 2.8237429    |
# | policy_loss        | -0.017927594 |
# | serial_timesteps   | 19200        |
# | time_elapsed       | 153          |
# | total_timesteps    | 19200        |
# | value_loss         | 6.794393     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.010681724  |
# | clipfrac           | 0.125        |
# | explained_variance | 0.233        |
# | fps                | 127          |
# | n_updates          | 151          |
# | policy_entropy     | 2.82357      |
# | policy_loss        | -0.003772345 |
# | serial_timesteps   | 19328        |
# | time_elapsed       | 154          |
# | total_timesteps    | 19328        |
# | value_loss         | 0.15317866   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0087403525 |
# | clipfrac           | 0.119140625  |
# | explained_variance | -7.9         |
# | fps                | 119          |
# | n_updates          | 152          |
# | policy_entropy     | 2.8237343    |
# | policy_loss        | -0.015825216 |
# | serial_timesteps   | 19456        |
# | time_elapsed       | 155          |
# | total_timesteps    | 19456        |
# | value_loss         | 0.0051089814 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.01905114   |
# | clipfrac           | 0.23242188   |
# | explained_variance | 0.676        |
# | fps                | 116          |
# | n_updates          | 153          |
# | policy_entropy     | 2.8223772    |
# | policy_loss        | -0.031731423 |
# | serial_timesteps   | 19584        |
# | time_elapsed       | 157          |
# | total_timesteps    | 19584        |
# | value_loss         | 0.0056226887 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.028572712  |
# | clipfrac           | 0.2265625    |
# | explained_variance | -0.264       |
# | fps                | 123          |
# | n_updates          | 154          |
# | policy_entropy     | 2.8205862    |
# | policy_loss        | -0.016351825 |
# | serial_timesteps   | 19712        |
# | time_elapsed       | 158          |
# | total_timesteps    | 19712        |
# | value_loss         | 0.019772619  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.011539547  |
# | clipfrac           | 0.15625      |
# | explained_variance | -0.979       |
# | fps                | 134          |
# | n_updates          | 155          |
# | policy_entropy     | 2.820786     |
# | policy_loss        | -0.010525234 |
# | serial_timesteps   | 19840        |
# | time_elapsed       | 159          |
# | total_timesteps    | 19840        |
# | value_loss         | 0.0016182474 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.011805757  |
# | clipfrac           | 0.115234375  |
# | explained_variance | -1.6         |
# | fps                | 134          |
# | n_updates          | 156          |
# | policy_entropy     | 2.8214924    |
# | policy_loss        | -0.013961369 |
# | serial_timesteps   | 19968        |
# | time_elapsed       | 160          |
# | total_timesteps    | 19968        |
# | value_loss         | 0.005765367  |
# -------------------------------------

# %%
from navrep.envs.e2eenv import E2ENavRepEnv, E2E1DNavRepEnv
from stable_baselines import PPO2
from navrep.tools.custom_policy import CustomPolicy, Custom1DPolicy, ARCH, _C
#env = E2ENavRepEnv(silent=True, scenario='train', adaptive=False, collect_statistics=False)
#obs = env.reset()
#print(obs.shape)
env = model.get_env()
obs = env.reset()
reward_sum = 0.0
for _ in range(1000):
    action, _ = model.predict(obs)
    obs, reward, done, _ = env.step(action)
    reward_sum += reward
    env.render()
    if done:
        print(reward_sum)
        reward_sum = 0.0
        obs = env.reset()

env.close()
# Out:
# [0.60668784]
# [1.4697067]
# [0.6385295]
# [-26.233183]
# [1.3319086]
# [-24.809328]
# [-24.958225]

# %%
import os
import warnings
from typing import Dict

import cv2  # pytype:disable=import-error
import numpy as np
from gym import spaces

from stable_baselines.common.base_class import BaseRLModel
from stable_baselines.common.vec_env import VecEnv, VecFrameStack
from stable_baselines.common.base_class import _UnvecWrapper

def generate_expert_traj(model, save_path=None, env=None, n_timesteps=0,
                         n_episodes=100, image_folder='recorded_images'):
    """
    Train expert controller (if needed) and record expert trajectories.

    .. note::

        only Box and Discrete spaces are supported for now.

    :param model: (RL model or callable) The expert model, if it needs to be trained,
        then you need to pass ``n_timesteps > 0``.
    :param save_path: (str) Path without the extension where the expert dataset will be saved
        (ex: 'expert_cartpole' -> creates 'expert_cartpole.npz').
        If not specified, it will not save, and just return the generated expert trajectories.
        This parameter must be specified for image-based environments.
    :param env: (gym.Env) The environment, if not defined then it tries to use the model
        environment.
    :param n_timesteps: (int) Number of training timesteps
    :param n_episodes: (int) Number of trajectories (episodes) to record
    :param image_folder: (str) When using images, folder that will be used to record images.
    :return: (dict) the generated expert trajectories.
    """

    # Retrieve the environment using the RL model
    if env is None and isinstance(model, BaseRLModel):
        env = model.get_env()

    assert env is not None, "You must set the env in the model or pass it to the function."

    is_vec_env = False
    if isinstance(env, VecEnv) and not isinstance(env, _UnvecWrapper):
        is_vec_env = True
        if env.num_envs > 1:
            warnings.warn("You are using multiple envs, only the data from the first one will be recorded.")

    # Sanity check
    assert (isinstance(env.observation_space, spaces.Box) or
            isinstance(env.observation_space, spaces.Discrete)), "Observation space type not supported"

    assert (isinstance(env.action_space, spaces.Box) or
            isinstance(env.action_space, spaces.Discrete)), "Action space type not supported"

    # Check if we need to record images
    obs_space = env.observation_space
    record_images = len(obs_space.shape) == 3 and obs_space.shape[-1] in [1, 3, 4] \
                    and obs_space.dtype == np.uint8
    if record_images and save_path is None:
        warnings.warn("Observations are images but no save path was specified, so will save in numpy archive; "
                      "this can lead to higher memory usage.")
        record_images = False

    if not record_images and len(obs_space.shape) == 3 and obs_space.dtype == np.uint8:
        warnings.warn("The observations looks like images (shape = {}) "
                      "but the number of channel > 4, so it will be saved in the numpy archive "
                      "which can lead to high memory usage".format(obs_space.shape))

    image_ext = 'jpg'
    if record_images:
        # We save images as jpg or png, that have only 3/4 color channels
        if isinstance(env, VecFrameStack) and env.n_stack == 4:
            # assert env.n_stack < 5, "The current data recorder does no support"\
            #                          "VecFrameStack with n_stack > 4"
            image_ext = 'png'

        folder_path = os.path.dirname(save_path)
        image_folder = os.path.join(folder_path, image_folder)
        os.makedirs(image_folder, exist_ok=True)
        print("=" * 10)
        print("Images will be recorded to {}/".format(image_folder))
        print("Image shape: {}".format(obs_space.shape))
        print("=" * 10)

    if n_timesteps > 0 and isinstance(model, BaseRLModel):
        model.learn(n_timesteps)

    actions = []
    observations = []
    rewards = []
    episode_returns = np.zeros((n_episodes,))
    episode_starts = []

    ep_idx = 0
    obs = env.reset()
    episode_starts.append(True)
    reward_sum = 0.0
    idx = 0
    # state and mask for recurrent policies
    state, mask = None, None

    if is_vec_env:
        mask = [True for _ in range(env.num_envs)]

    while ep_idx < n_episodes:
        obs_ = obs[0] if is_vec_env else obs
        if record_images:
            image_path = os.path.join(image_folder, "{}.{}".format(idx, image_ext))
            # Convert from RGB to BGR
            # which is the format OpenCV expect
            if obs_.shape[-1] == 3:
                obs_ = cv2.cvtColor(obs_, cv2.COLOR_RGB2BGR)
            cv2.imwrite(image_path, obs_)
            observations.append(image_path)
        else:
            observations.append(obs_)

        if isinstance(model, BaseRLModel):
            action, state = model.predict(obs, state=state, mask=mask)
        else:
            action = model(obs)

        obs, reward, done, _ = env.step(action)

        # Use only first env
        if is_vec_env:
            mask = [done[0] for _ in range(env.num_envs)]
            action = np.array([action[0]])
            reward = np.array([reward[0]])
            done = np.array([done[0]])

        actions.append(action)
        rewards.append(reward)
        episode_starts.append(done)
        reward_sum += reward
        idx += 1
        if done:
            if not is_vec_env:
                obs = env.reset()
                # Reset the state in case of a recurrent policy
                state = None

            episode_returns[ep_idx] = reward_sum
            reward_sum = 0.0
            ep_idx += 1

    if isinstance(env.observation_space, spaces.Box) and not record_images:
        observations = np.concatenate(observations).reshape((-1,) + env.observation_space.shape)
    elif isinstance(env.observation_space, spaces.Discrete):
        observations = np.array(observations).reshape((-1, 1))
    elif record_images:
        observations = np.array(observations)

    if isinstance(env.action_space, spaces.Box):
        actions = np.concatenate(actions).reshape((-1,) + env.action_space.shape)
    elif isinstance(env.action_space, spaces.Discrete):
        actions = np.array(actions).reshape((-1, 1))

    rewards = np.array(rewards)
    episode_starts = np.array(episode_starts[:-1])

    assert len(observations) == len(actions)

    numpy_dict = {
        'actions': actions,
        'obs': observations,
        'rewards': rewards,
        'episode_returns': episode_returns,
        'episode_starts': episode_starts
    }  # type: Dict[str, np.ndarray]

    for key, val in numpy_dict.items():
        print(key, val.shape)

    if save_path is not None:
        np.savez(save_path, **numpy_dict)

    env.close()

    return numpy_dict

# %%
tmp = np.load('FORCA_02.npz')
print(tmp['episode_starts'][tmp['episode_starts']==True])
print(tmp['rewards'][tmp['rewards']>30])
# Out:
# [ True  True  True  True  True  True  True  True  True  True]
# [100. 100. 100. 100. 100. 100. 100.]
